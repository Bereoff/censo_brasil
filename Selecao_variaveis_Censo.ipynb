# %% [markdown]
# *   Não consta a UF de Brasília
# *   A tabela 6 não foi inserida. Tratava-se de unidades domésticas unipessoais, nuclear, estendida e composta... pareceu complexo e fora do escopo deste trabalho.

# %%
import pandas as pd

# %% [markdown]
# ## Criação da TABELA_CENSO_2010

# %%
""""
  Tabela com Cidades do IdSUS
  Importa a tabela com cidades do idSUS 'idSUS_Cidades' e a manipula para conca-
  tenar em nomeCidade_UF.
  Já importa também a nota no idSUS e o grupo a que pertence.
  
  Objetivo: checar se as ciddaes em idSUS_Cidades batem com as cidades nos 
  arquivos IBGE.

Returns:
  TABELA_CENSO_IDSUS_2010 (tabela):

Todo:
  *É preciso checar se os nomes das cidades importadas dessa tabela batem com as
  cidades do IBGE. Se não, corrigir!
"""

idSUS_path = "/content/drive/MyDrive/preditor SUS/idSUS2010_cidades.xlsx"
idSUS_Cidades = pd.read_excel(idSUS_path,usecols='A,C:E')

# %%
idSUS_Cidades
# Out:
#                   Município  UF idsus_fx Grupo Homogêneo
# 0     Alta Floresta D'Oeste  RO  4 a 4,9             GH3
# 1                 Ariquemes  RO  4 a 4,9             GH3
# 2                    Cabixi  RO  4 a 4,9             GH5
# 3                    Cacoal  RO  4 a 4,9             GH3
# 4                Cerejeiras  RO  4 a 4,9             GH5
# ...                     ...  ..      ...             ...
# 5560             Vianópolis  GO  5 a 5,9             GH5
# 5561         Vicentinópolis  GO  4 a 4,9             GH5
# 5562               Vila Boa  GO  5 a 5,9             GH5
# 5563          Vila Propício  GO  4 a 4,9             GH5
# 5564               Brasília  DF  5 a 5,9             GH1
#
# [5565 rows x 4 columns]

# %%
""" variáveis
  Lista com a cópia dos nomes dados para as features importadas das planilhas 
  do Censo.
  
  # !!!NÃO MODIFICAR AQUI SEM ANTES MODIFICAR NA 'exec_UF'!!!. 
"""

variáveis = [
 'Popu_GERAL','Popu_domi_URBANA(%)','Popu_domi_RURAL(%)','Popu_HOMEM(%)','Pop_MULHER(%)','Razão_HOMEM/MULHER',
'Popu_GERAL_0_5anos(%)', 'Popu_GERAL_6_14anos(%)', 'Popu_GERAL_15_24anos(%)', 'Popu_GERAL_25_39anos(%)', 'Popu_GERAL_40_59anos(%)', 'Popu_GERAL_60+anos(%)', 
'Popu_res_URBANA', 'Popu_res_URBANA_0_5anos(%)', 'Popu_res_URBANA_6_14anos(%)', 'Popu_res_URBANA_15_24anos(%)', 'Popu_res_URBANA_25_39anos(%)', 'Popu_res_URBANA_40_59anos(%)', 'Popu_res_URBANA_60+anos(%)', 
'Popu_res_RURAL', 'Popu_res_RURAL_0_5anos(%)', 'Popu_res_RURAL_6_14anos(%)', 'Popu_res_RURAL_15_24anos(%)', 'Popu_res_RURAL_25_39anos(%)', 'Popu_res_RURAL_40_59anos(%)', 'Popu_res_RURAL_60+anos(%)',
'Adulto_analfabeto_GERAL_15+anos','Adulto_analfabeto_GERAL_15+anos(%)', 'Adulto_analfabeto_GERAL_15a24anos','Adulto_analfabeto_GERAL_15a24anos(%)','Adulto_analfabeto_GERAL_25a39anos','Adulto_analfabeto_GERAL_25a39anos(%)', 'Adulto_analfabeto_GERAL_40a59anos','Adulto_analfabeto_GERAL_40a59anos(%)', 'Adulto_analfabeto_GERAL_60+anos','Adulto_analfabeto_GERAL_60+anos(%)',
'Adulto_analfabeto_BRANCO_15+anos','Adulto_analfabeto_BRANCO_15+anos(%)', 'Adulto_analfabeto_BRANCO_15a24anos','Adulto_analfabeto_BRANCO_15a24anos(%)', 'Adulto_analfabeto_BRANCO_25a39anos','Adulto_analfabeto_BRANCO_25a39anos(%)', 'Adulto_analfabeto_BRANCO_40a59anos','Adulto_analfabeto_BRANCO_40a59anos(%)', 'Adulto_analfabeto_BRANCO_60+anos','Adulto_analfabeto_BRANCO_60+anos(%)',
'Adulto_analfabeto_PRETO_15+anos','Adulto_analfabeto_PRETO_15+anos(%)', 'Adulto_analfabeto_PRETO_15a24anos','Adulto_analfabeto_PRETO_15a24anos(%)', 'Adulto_analfabeto_PRETO_25a39anos','Adulto_analfabeto_PRETO_25a39anos(%)', 'Adulto_analfabeto_PRETO_40a59anos','Adulto_analfabeto_PRETO_40a59anos(%)', 'Adulto_analfabeto_PRETO_60+anos','Adulto_analfabeto_PRETO_60+anos(%)',
'Adulto_analfabeto_PARDO_15+anos','Adulto_analfabeto_PARDO_15+anos(%)', 'Adulto_analfabeto_PARDO_15a24anos','Adulto_analfabeto_PARDO_15a24anos(%)', 'Adulto_analfabeto_PARDO_25a39anos','Adulto_analfabeto_PARDO_25a39anos(%)', 'Adulto_analfabeto_PARDO_40a59anos','Adulto_analfabeto_PARDO_40a59anos(%)', 'Adulto_analfabeto_PARDO_60+anos','Adulto_analfabeto_PARDO_60+anos(%)',
'Adulto_analfabeto_AMARELO_15+anos','Adulto_analfabeto_AMARELO_15+anos(%)', 'Adulto_analfabeto_AMARELO_15a24anos','Adulto_analfabeto_AMARELO_15a24anos(%)', 'Adulto_analfabeto_AMARELO_25a39anos','Adulto_analfabeto_AMARELO_25a39anos(%)', 'Adulto_analfabeto_AMARELO_40a59anos','Adulto_analfabeto_AMARELO_40a59anos(%)', 'Adulto_analfabeto_AMARELO_60+anos','Adulto_analfabeto_AMARELO_60+anos(%)',
'Adulto_analfabeto_INDIGENA_15+anos','Adulto_analfabeto_INDIGENA_15+anos(%)', 'Adulto_analfabeto_INDIGENA_15a24anos','Adulto_analfabeto_INDIGENA_15a24anos(%)', 'Adulto_analfabeto_INDIGENA_25a39anos','Adulto_analfabeto_INDIGENA_25a39anos(%)', 'Adulto_analfabeto_INDIGENA_40a59anos','Adulto_analfabeto_INDIGENA_40a59anos(%)', 'Adulto_analfabeto_INDIGENA_60+anos','Adulto_analfabeto_INDIGENA_60+anos(%)',
'Unid_doméstica_GERAL_total','Unid_doméstica_GERAL_único_responsável(%)', 'Unid_doméstica_GERAL_+de1_responsável(%)','Unid_doméstica_HOMEM_total', 'Unid_doméstica_HOMEM_único_responsável(%)', 'Unid_doméstica_HOMEM_+de1_responsável(%)','Unid_doméstica_MULHER_total', 'Unid_doméstica_MULHER_único_responsável(%)', 'Unid_doméstica_MULHER_+de1_responsável(%)',   
'Unid_doméstica_casal_total', 'Unid_doméstica_casal_único_responsável(%)','Unid_doméstica_casal_+de1_responsável(%)', 'Unid_doméstica_casal+filhos/parentes_total', 'Unid_doméstica_casal+filhos/parentes_único_responsável(%)','Unid_doméstica_casal+filhos/parentes_+de1_responsável(%)',  'Unid_doméstica_outros_total', 'Unid_doméstica_outros_único_responsável(%)','Unid_doméstica_outros_+de1_responsável(%)',
'Unid_doméstica_GERAL_saneamento_adequado(%)', 'Unid_doméstica_GERAL_saneamento_semi-adequado(%)', 'Unid_doméstica_GERAL_saneamento_inadequado(%)',
'Unid_doméstica_URBANA_saneamento_adequado(%)', 'Unid_doméstica_URBANA_saneamento_semi-adequado(%)', 'Unid_doméstica_URBANA_saneamento_inadequado(%)',
'Unid_doméstica_RURAL_saneamento_adequado(%)', 'Unid_doméstica_RURAL_saneamento_semi-adequado(%)', 'Unid_doméstica_RURAL_saneamento_inadequado(%)',
'Renda_mensal_percapta_GERAL_valor_médio', 'Renda_mensal_percapta_GERAL_1oQuartil','Renda_mensal_percapta_GERAL_2oQuartil','Renda_mensal_percapta_GERAL_3oQuartil',
'Renda_mensal_percapta_URBANA_valor_médio', 'Renda_mensal_percapta_URBANA_1oQuartil','Renda_mensal_percapta_URBANA_2oQuartil','Renda_mensal_percapta_URBANA_3oQuartil',
'Renda_mensal_percapta_RURAL_valor_médio', 'Renda_mensal_percapta_RURAL_1oQuartil','Renda_mensal_percapta_RURAL_2oQuartil','Renda_mensal_percapta_RURAL_3oQuartil',
'Renda_mensal_10anos+_HOMEM_renda_media', 'Renda_mensal_10anos+_MULHER_renda_media', 'Renda_mensal_10anos+_HOMEM_renda_mediana', 'Renda_mensal_10anos+_MULHER_renda_media','Renda_mensal_10anos+_Razão_HOMEM/MULHER_renda_media','Renda_mensal_10anos+_Razão_HOMEM/MULHER_renda_mediana',
'Renda_mensal_10anos+_BRANCO_renda_media','Renda_mensal_10anos+_PRETO_renda_media','Renda_mensal_10anos+_PARDO_renda_media','Renda_mensal_10anos+_AMARELO_renda_media','Renda_mensal_10anos+_INDIGENA_renda_media',
'Razão_renda_mensal_10anos+_BRANCO/PRETO','Razão_renda_mensal_10anos+_BRANCO/PARDO','Razão_renda_mensal_10anos+_BRANCO/AMARELO','Razão_renda_mensal_10anos+_BRANCO/INDIGENA','Razão_renda_mensal_10anos+_PRETO/PARDO',
'Popu_permanente_GERAL_total','Popu_permanente_GERAL_renda_atéR$70','Popu_permanente_GERAL_renda_atéR$127.50(1/4)','Popu_permanente_GERAL_renda_atéR$255.00(1/2)','Popu_permanente_GERAL_renda_até60%daMedianaBrasil(R$255.00)',
'Popu_permanente_URBANA_total','Popu_permanente_URBANA_renda_atéR$70','Popu_permanente_URBANA_renda_atéR$127.50(1/4)','Popu_permanente_URBANA_renda_atéR$255(1/2)','Popu_permanente_URBANA_renda_até60%daMedianaBrasil(R$249)',
'Popu_permanente_RURAL_total','Popu_permanente_RURAL_renda_atéR$70','Popu_permanente_RURAL_renda_atéR$127.50(1/4)','Popu_permanente_RURAL_renda_atéR$255(1/2)','Popu_permanente_RURAL_renda_até60%daMedianaBrasil(R$102)',
'Popu_permanente_saneamento_adequado_total', 'Popu_permanente_saneamento_adequado_renda_atéR$70','Popu_permanente_saneamento_adequado_renda_atéR$128(1/4)','Popu_permanente_saneamento_adequado_renda_atéR$255(1/2)' ,'Popu_permanente_saneamento_adequado_renda_até60%daMedianaBrasil(R$225)',
'Proporção_analfabetos_15anos+_2000(%)', 'Proporção_analfabetos_15anos+_2010(%)', 'Proporção_analfabetos_15a24anos_2000(%)', 'Proporção_analfabetos_15a24anos_2010(%)', 'Proporção_analfabetos_25a59anos_2000(%)', 'Proporção_analfabetos_25a59anos_2010(%)', 'Proporção_analfabetos_60+anos_2000(%)', 'Proporção_analfabetos_60+anos_2010(%)',
'Proporção_domicílios_saneamento_adequado_2000(%)','Proporção_domicílios_saneamento_adequado_2010(%)','Proporção_domicílios_saneamento_semi-adequado_2000(%)','Proporção_domicílios_saneamento_semi-adequado_2010(%)','Proporção_domicílios_saneamento_inadequado_2000(%)','Proporção_domicílios_saneamento_inadequado_2010(%)',
'Proporção_criança_com_responsável_analfabeto_2000(%)','Proporção_criança_com_responsável_analfabeto_2010(%)','Proporção_criança_com_saneamento_inadequado_2000(%)','Proporção_criança_com_saneamento_inadequado_2010(%)','Proporção_criança_com_responsável_analfabeto&saneamento_inadequado_2000(%)','Proporção_criança_com_responsável_analfabeto&saneamento_inadequado_2010(%)',
'Criança_10anos_analfabeta_total','Criança_10anos_analfabeta_(%)']

# %%
len(variáveis)
# Out:
# 183

# %% [markdown]
# ## Extração de features do Censo para a TABELA_CENSO_2010

# %%
# Dicionário com as UFs e nome dos Estados conforme consta na pasta do Censo
uf_estado = {  
  'AC':'acre',
  'AL':'alagoas',
  'AP':'amapa',
  'AM':'amazonas',
  'BA':'bahia',
  'CE':'ceara',
  'ES':'espirito_santo',
  'GO':'goias',
  'MA':'maranhao',
  'MT':'mato_grosso',
  'MS':'mato_grosso_do_sul',
  'MG':'minas_gerais',
  'PA':'para',
  'PB':'paraiba',
  'PR':'parana',
  'PE':'pernambuco',
  'PI':'piaui',
  'RJ':'rio_de_janeiro',
  'RN':'rio_grande_do_norte',
  'RS':'rio_grande_do_sul',
  'RO':'rondonia',
  'RR':'roraima',
  'SC':'santa_catarina',
  'SP':'sao_paulo',
  'SE':'sergipe',
  'TO':'tocantins',   
}

# %%
""" Função 'exec_UF'
  Função que recebe o nome do estado, importa cada uma das planilhas do Estado 
  como dfs e chama a função 'func_extract' para cada planilha.
  
  Para cada uma das planilhas, os nomes das features é passado como string 
  (que foi copiado na lista 'variáveis', usada para criar as colunas de 
  'TABELA_CENSO_2010').

OBS:
  Atribuir o novo endereço da pasta "indicadores sociais municipais" na variável 
  folderpath caso mude o arquivo de lugar. 

Args: 
  uf (string) singla da unidade federativa em uppercase.
  nome_estado (string) nome do estado em lowercase.

Return:
  Roda a func_extract para todas as planilhas do Estado.
"""

def exec_UF(uf,nome_estado):
  folderpath = '/content/drive/MyDrive/preditor SUS/indicadores_sociais_municipais'

  '''TAB01'''
  file1 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab1.xls'
  var1 = ['Cidades','Popu_GERAL','Popu_domi_URBANA(%)','Popu_domi_RURAL(%)','Popu_HOMEM(%)','Pop_MULHER(%)','Razão_HOMEM/MULHER'] 
  df1 = pd.read_excel(file1, sheet_name='tab1', usecols='B:H', skiprows=6, names = var1)
  func_extract(df1, var1)

  '''TAB02'''
  file2 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab2.xls'
  # Aba A --> Já tem a população residente GERAL Total naTab1
  var2a = ['Cidades', 'Popu_GERAL_0_5anos(%)', 'Popu_GERAL_6_14anos(%)', 'Popu_GERAL_15_24anos(%)', 'Popu_GERAL_25_39anos(%)', 'Popu_GERAL_40_59anos(%)', 'Popu_GERAL_60+anos(%)'] 
  df2a = pd.read_excel(file2, sheet_name='tab2A', usecols='B,D:I', skiprows=7, names = var2a)
  func_extract(df2a, var2a)
  # Aba B
  var2b = ['Cidades','Popu_res_URBANA', 'Popu_res_URBANA_0_5anos(%)', 'Popu_res_URBANA_6_14anos(%)', 'Popu_res_URBANA_15_24anos(%)', 'Popu_res_URBANA_25_39anos(%)', 'Popu_res_URBANA_40_59anos(%)', 'Popu_res_URBANA_60+anos(%)'] 
  df2b = pd.read_excel(file2, sheet_name='tab2B', usecols='B:I', skiprows=7, names = var2b)
  func_extract(df2b, var2b)
  # Aba C
  var2c = ['Cidades','Popu_res_RURAL', 'Popu_res_RURAL_0_5anos(%)', 'Popu_res_RURAL_6_14anos(%)', 'Popu_res_RURAL_15_24anos(%)', 'Popu_res_RURAL_25_39anos(%)', 'Popu_res_RURAL_40_59anos(%)', 'Popu_res_RURAL_60+anos(%)'] 
  df2b = pd.read_excel(file2, sheet_name='tab2C', usecols='B:I', skiprows=7, names = var2c)
  func_extract(df2c, var2c)

  '''TAB03'''
  file3 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab3.xls'
  # Aba A
  var3a = ['Cidades', 'Adulto_analfabeto_GERAL_15+anos','Adulto_analfabeto_GERAL_15+anos(%)', 'Adulto_analfabeto_GERAL_15a24anos','Adulto_analfabeto_GERAL_15a24anos(%)','Adulto_analfabeto_GERAL_25a39anos','Adulto_analfabeto_GERAL_25a39anos(%)', 'Adulto_analfabeto_GERAL_40a59anos','Adulto_analfabeto_GERAL_40a59anos(%)', 'Adulto_analfabeto_GERAL_60+anos','Adulto_analfabeto_GERAL_60+anos(%)']
  df3a = pd.read_excel(file3, sheet_name='tab3A', usecols='B:L', skiprows=8, names = var3a)
  func_extract(df3a, var3a)
  # Aba B
  var3b = ['Cidades', 'Adulto_analfabeto_BRANCO_15+anos','Adulto_analfabeto_BRANCO_15+anos(%)', 'Adulto_analfabeto_BRANCO_15a24anos','Adulto_analfabeto_BRANCO_15a24anos(%)', 'Adulto_analfabeto_BRANCO_25a39anos','Adulto_analfabeto_BRANCO_25a39anos(%)', 'Adulto_analfabeto_BRANCO_40a59anos','Adulto_analfabeto_BRANCO_40a59anos(%)', 'Adulto_analfabeto_BRANCO_60+anos','Adulto_analfabeto_BRANCO_60+anos(%)']
  df3b = pd.read_excel(file3, sheet_name='tab3B', usecols='B:L', skiprows=8, names = var3b)
  func_extract(df3b, var3b)
  # Aba C
  var3c = ['Cidades', 'Adulto_analfabeto_PRETO_15+anos','Adulto_analfabeto_PRETO_15+anos(%)', 'Adulto_analfabeto_PRETO_15a24anos','Adulto_analfabeto_PRETO_15a24anos(%)', 'Adulto_analfabeto_PRETO_25a39anos','Adulto_analfabeto_PRETO_25a39anos(%)', 'Adulto_analfabeto_PRETO_40a59anos','Adulto_analfabeto_PRETO_40a59anos(%)', 'Adulto_analfabeto_PRETO_60+anos','Adulto_analfabeto_PRETO_60+anos(%)']
  df3c = pd.read_excel(file3, sheet_name='tab3C', usecols='B:L', skiprows=8, names = var3c)
  func_extract(df3c, var3c)
  # Aba D
  var3d = ['Cidades', 'Adulto_analfabeto_PARDO_15+anos','Adulto_analfabeto_PARDO_15+anos(%)', 'Adulto_analfabeto_PARDO_15a24anos','Adulto_analfabeto_PARDO_15a24anos(%)', 'Adulto_analfabeto_PARDO_25a39anos','Adulto_analfabeto_PARDO_25a39anos(%)', 'Adulto_analfabeto_PARDO_40a59anos','Adulto_analfabeto_PARDO_40a59anos(%)', 'Adulto_analfabeto_PARDO_60+anos','Adulto_analfabeto_PARDO_60+anos(%)']
  df3d = pd.read_excel(file3, sheet_name='tab3D', usecols='B:L', skiprows=8, names = var3d)
  func_extract(df3d, var3d)
  # Aba E
  var3e = ['Cidades', 'Adulto_analfabeto_AMARELO_15+anos','Adulto_analfabeto_AMARELO_15+anos(%)', 'Adulto_analfabeto_AMARELO_15a24anos','Adulto_analfabeto_AMARELO_15a24anos(%)', 'Adulto_analfabeto_AMARELO_25a39anos','Adulto_analfabeto_AMARELO_25a39anos(%)', 'Adulto_analfabeto_AMARELO_40a59anos','Adulto_analfabeto_AMARELO_40a59anos(%)', 'Adulto_analfabeto_AMARELO_60+anos','Adulto_analfabeto_AMARELO_60+anos(%)']
  df3e = pd.read_excel(file3, sheet_name='tab3E', usecols='B:L', skiprows=8, names = var3e)
  func_extract(df3e, var3e)
  # Aba F
  var3f = ['Cidades', 'Adulto_analfabeto_INDIGENA_15+anos','Adulto_analfabeto_INDIGENA_15+anos(%)', 'Adulto_analfabeto_INDIGENA_15a24anos','Adulto_analfabeto_INDIGENA_15a24anos(%)', 'Adulto_analfabeto_INDIGENA_25a39anos','Adulto_analfabeto_INDIGENA_25a39anos(%)', 'Adulto_analfabeto_INDIGENA_40a59anos','Adulto_analfabeto_INDIGENA_40a59anos(%)', 'Adulto_analfabeto_INDIGENA_60+anos','Adulto_analfabeto_INDIGENA_60+anos(%)']
  df3f = pd.read_excel(file3, sheet_name='tab3F', usecols='B:L', skiprows=8, names = var3f)
  func_extract(df3f, var3f)

  '''TAB04'''
  file4 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab4.xls'
  var4 = ['Cidades','Unid_doméstica_GERAL_total','Unid_doméstica_GERAL_único_responsável(%)', 'Unid_doméstica_GERAL_+de1_responsável(%)','Unid_doméstica_HOMEM_total', 'Unid_doméstica_HOMEM_único_responsável(%)', 'Unid_doméstica_HOMEM_+de1_responsável(%)','Unid_doméstica_MULHER_total', 'Unid_doméstica_MULHER_único_responsável(%)', 'Unid_doméstica_MULHER_+de1_responsável(%)']   
  df4 = pd.read_excel(file4, sheet_name='tab4', usecols='B:K', skiprows=8, names = var4)
  func_extract(df4, var4)

  '''TAB05 ---> as 3 colunas de "total" já aparecem na tab4, não extrair'''
  file5 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab5.xls'
  var5 = ['Cidades', 'Unid_doméstica_casal_total', 'Unid_doméstica_casal_único_responsável(%)','Unid_doméstica_casal_+de1_responsável(%)', 'Unid_doméstica_casal+filhos/parentes_total', 'Unid_doméstica_casal+filhos/parentes_único_responsável(%)','Unid_doméstica_casal+filhos/parentes_+de1_responsável(%)',  'Unid_doméstica_outros_total', 'Unid_doméstica_outros_único_responsável(%)','Unid_doméstica_outros_+de1_responsável(%)']
  df5 = pd.read_excel(file5, sheet_name='tab5', usecols='B,F:N', skiprows=8, names = var5)

  '''TAB06 --->'''
  #Complexa demais

  '''TAB07 --->'''
  file7 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab7.xls'
  # Aba A
  var7a = ['Cidades','Unid_doméstica_GERAL_saneamento_adequado(%)', 'Unid_doméstica_GERAL_saneamento_semi-adequado(%)', 'Unid_doméstica_GERAL_saneamento_inadequado(%)']
  df7a = pd.read_excel(file7, sheet_name='tab7A', usecols='B,D:F', skiprows=8, names = var7a)
  func_extract(df7a, var7a)
  # Aba B
  var7b = ['Cidades','Unid_doméstica_URBANA_saneamento_adequado(%)', 'Unid_doméstica_URBANA_saneamento_semi-adequado(%)', 'Unid_doméstica_URBANA_saneamento_inadequado(%)']
  df7b = pd.read_excel(file7, sheet_name='tab7B', usecols='B,D:F', skiprows=8, names = var7b)
  func_extract(df7b, var7b)
  # Aba C
  var7c = ['Cidades','Unid_doméstica_RURAL_saneamento_adequado(%)', 'Unid_doméstica_RURAL_saneamento_semi-adequado(%)', 'Unid_doméstica_RURAL_saneamento_inadequado(%)']
  df7c = pd.read_excel(file7, sheet_name='tab7C', usecols='B,D:F', skiprows=8, names = var7c)
  func_extract(df7c, var7c)

  '''TAB08 --->'''
  file8 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab8.xls'
  # Aba A
  var8a = ['Cidades','Renda_mensal_percapta_GERAL_valor_médio', 'Renda_mensal_percapta_GERAL_1oQuartil','Renda_mensal_percapta_GERAL_2oQuartil','Renda_mensal_percapta_GERAL_3oQuartil']
  df8a = pd.read_excel(file8, sheet_name='tab8A', usecols='B,D:F', skiprows=8, names = var8a)
  func_extract(df8a, var8a)
  # Aba B
  var8b = ['Cidades','Renda_mensal_percapta_URBANA_valor_médio', 'Renda_mensal_percapta_URBANA_1oQuartil','Renda_mensal_percapta_URBANA_2oQuartil','Renda_mensal_percapta_URBANA_3oQuartil']
  df8b = pd.read_excel(file8, sheet_name='tab8B', usecols='B,D:F', skiprows=8, names = var8b)
  func_extract(df8b, var8b)
  # Aba C
  var8c = ['Cidades','Renda_mensal_percapta_RURAL_valor_médio', 'Renda_mensal_percapta_RURAL_1oQuartil','Renda_mensal_percapta_RURAL_2oQuartil','Renda_mensal_percapta_RURAL_3oQuartil']
  df8c = pd.read_excel(file8, sheet_name='tab8C', usecols='B,D:F', skiprows=8, names = var8c)
  func_extract(df8c, var8c)

  '''TAB09 --->'''
  file9 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab9.xls'
  var9 = ['Cidades', 'Renda_mensal_10anos+_HOMEM_renda_media', 'Renda_mensal_10anos+_MULHER_renda_media', 'Renda_mensal_10anos+_HOMEM_renda_mediana', 'Renda_mensal_10anos+_MULHER_renda_media','Renda_mensal_10anos+_Razão_HOMEM/MULHER_renda_media','Renda_mensal_10anos+_Razão_HOMEM/MULHER_renda_mediana']
  df9 = pd.read_excel(file9, sheet_name='tab9', usecols='B:H', skiprows=8, names = var9)
  func_extract(df9, var9)

  '''TAB10 --->'''
  file10 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab10.xls'
  var10 = ['Cidades','Renda_mensal_10anos+_BRANCO_renda_media','Renda_mensal_10anos+_PRETO_renda_media','Renda_mensal_10anos+_PARDO_renda_media','Renda_mensal_10anos+_AMARELO_renda_media','Renda_mensal_10anos+_INDIGENA_renda_media']
  df10 = pd.read_excel(file10, sheet_name='tab10', usecols='B:G', skiprows=6, names = var10)
  func_extract(df10, var10)

  '''TAB11 --->'''
  file11 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab11.xls'
  var11 = ['Cidades','Razão_renda_mensal_10anos+_BRANCO/PRETO','Razão_renda_mensal_10anos+_BRANCO/PARDO','Razão_renda_mensal_10anos+_BRANCO/AMARELO','Razão_renda_mensal_10anos+_BRANCO/INDIGENA','Razão_renda_mensal_10anos+_PRETO/PARDO']
  df11 = pd.read_excel(file11, sheet_name='tab11', usecols='B:G', skiprows=6, names = var11)
  func_extract(df11, var11)

  '''TAB12 --->'''
  file12 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab12.xls'
  # Aba A
  var12a = ['Cidades','Popu_permanente_GERAL_total','Popu_permanente_GERAL_renda_atéR$70','Popu_permanente_GERAL_renda_atéR$127.50(1/4)','Popu_permanente_GERAL_renda_atéR$255.00(1/2)','Popu_permanente_GERAL_renda_até60%daMedianaBrasil(R$255.00)']
  df12a = pd.read_excel(file12, sheet_name='tab12A', usecols='B:G', skiprows=6, names = var12a)
  func_extract(df12a, var12a)
  # Aba B
  var12b = ['Cidades','Popu_permanente_URBANA_total','Popu_permanente_URBANA_renda_atéR$70','Popu_permanente_URBANA_renda_atéR$127.50(1/4)','Popu_permanente_URBANA_renda_atéR$255(1/2)','Popu_permanente_URBANA_renda_até60%daMedianaBrasil(R$249)']
  df12b = pd.read_excel(file12, sheet_name='tab12B', usecols='B:G', skiprows=6, names = var12b)
  func_extract(df12b, var12b)
  # Aba C
  var12c = ['Cidades','Popu_permanente_RURAL_total','Popu_permanente_RURAL_renda_atéR$70','Popu_permanente_RURAL_renda_atéR$127.50(1/4)','Popu_permanente_RURAL_renda_atéR$255(1/2)','Popu_permanente_RURAL_renda_até60%daMedianaBrasil(R$102)']
  df12c = pd.read_excel(file12, sheet_name='tab12C', usecols='B:G', skiprows=6, names = var12c)
  func_extract(df12c, var12c)

  '''TAB13 --->'''
  file13 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab13.xls'
  var13 = ['Cidades', 'Popu_permanente_saneamento_adequado_total', 'Popu_permanente_saneamento_adequado_renda_atéR$70','Popu_permanente_saneamento_adequado_renda_atéR$128(1/4)','Popu_permanente_saneamento_adequado_renda_atéR$255(1/2)' ,'Popu_permanente_saneamento_adequado_renda_até60%daMedianaBrasil(R$225)']
  df13 = pd.read_excel(file13, sheet_name='tab13', usecols='B:G', skiprows=8, names = var13)
  func_extract(df13, var13)

  '''TAB14 --->'''
  file14 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab14.xls'
  var14 = ['Cidades', 'Proporção_analfabetos_15anos+_2000(%)', 'Proporção_analfabetos_15anos+_2010(%)', 'Proporção_analfabetos_15a24anos_2000(%)', 'Proporção_analfabetos_15a24anos_2010(%)', 'Proporção_analfabetos_25a59anos_2000(%)', 'Proporção_analfabetos_25a59anos_2010(%)', 'Proporção_analfabetos_60+anos_2000(%)', 'Proporção_analfabetos_60+anos_2010(%)']
  df14 = pd.read_excel(file14, sheet_name='tab14', usecols='B:J', skiprows=8, names = var14)
  func_extract(df14, var14)

  '''TAB15 --->'''
  file15 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab15.xls'
  var15 = ['Cidades', 'Proporção_domicílios_saneamento_adequado_2000(%)','Proporção_domicílios_saneamento_adequado_2010(%)','Proporção_domicílios_saneamento_semi-adequado_2000(%)','Proporção_domicílios_saneamento_semi-adequado_2010(%)','Proporção_domicílios_saneamento_inadequado_2000(%)','Proporção_domicílios_saneamento_inadequado_2010(%)']
  df15 = pd.read_excel(file15, sheet_name='tab15', usecols='B:H', skiprows=8, names = var15)
  func_extract(df15, var15)

  '''TAB16 --->'''
  file16 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab16.xls'
  var16 = ['Cidades','Proporção_criança_com_responsável_analfabeto_2000(%)','Proporção_criança_com_responsável_analfabeto_2010(%)','Proporção_criança_com_saneamento_inadequado_2000(%)','Proporção_criança_com_saneamento_inadequado_2010(%)','Proporção_criança_com_responsável_analfabeto&saneamento_inadequado_2000(%)','Proporção_criança_com_responsável_analfabeto&saneamento_inadequado_2010(%)']
  df16 = pd.read_excel(file16, sheet_name='tab16', usecols='B:H', skiprows=8, names = var16)
  func_extract(df16, var16)

  '''TAB17 --->'''
  file17 = str(folderpath)+'/'+str(nome_estado)+'/'+str(nome_estado)+'_tab17.xls'
  var17 = ['Cidades','Criança_10anos_analfabeta_total','Criança_10anos_analfabeta_(%)']
  df17 = pd.read_excel(file17, sheet_name='tab17', usecols='B:D', skiprows=6, names = var17)
  func_extract(df17, var17)

# %%
Essa função vai ser chamada na função exec_UF


#EXTRAI OS DADOS DA PLANILHA DO CENSO E COLOCA NA 'TABELA_CENSO_2010'
def func_extract(df,features):
  for cidade in Municipios: 
    if cidade[-2:] == UF:
      cid = cidade[:-3]
      for var in features 
        TABELA_CENSO_2010[[cidade],[var]] = df.loc[[cid],[var]]

# %%
FUNÇ
#PREENCHER A TABELA 'TABELA_CENSO_2010'
for uf,nome_estado in uf_estado.items():
  exec_UF(uf,nome_estado)
